# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\glori\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
url = 'https://www.trulia.com/for_sale/36.63199,38.40726,-78.77798,-76.20855_xy/9_zm/'
browser.visit(url)

# %%
housePrices = []
houseRegion = []
houseSqrFt = []
houseBath = []
houseBed = []

for x in range(1, 3):
    
    print(f'Processing Page {x} - Initialize', end='\r')
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    prices = soup.find_all('div', {'data-testid' : "property-price"})
    beds = soup.find_all('div', {'data-testid' : "property-beds"})
    baths = soup.find_all('div', {'data-testid' : "property-baths"})
    sqrFt = soup.find_all('div', {'data-testid' : "property-floorSpace"})
    region = soup.find_all('div', {'data-testid' : "property-region"})
    print(f'Processing Page {x} - Data scrape', end = '\r')

    for i, price in enumerate(prices):        
        housePrices.append(price.text)
        houseBed.append(beds[i].text[0])
        houseBath.append(baths[i].text[0])
        houseSqrFt.append(sqrFt[i].text[0])
        houseRegion.append(region[i].text)
    print(f'Processing Page {x} - List append', end = '\r')  

# Find next page button
    browser.find_by_xpath('//*[@id="resultsColumn"]/nav/ul/li[8]/a/div/svg')
    print(f'Processing Page {x} - Next Page', end = '\r')
# Out:
# Processing Page 2 - Next Pagend

# %%
soup.find_all('div', {'data-testid' : "property-baths"})[1].text
# Out:
# '2ba'

# %%
soup.find_all('div', {'data-testid' : "property-baths"})[1].text
# Out:
# '2ba'

# %%
house_df = pd.DataFrame(
    {
        'Prices': housePrices,
        'Beds': houseBed,
        'Baths': houseBath,
        'SquareFt': houseSqrFt,
        'Loc': houseRegion
    }

)

# %%
try:
    house_df.SquareFt = house_df.SquareFt.stri.replace(',','').astype(float)
except:
    print('Data already converted')
try:
    house_df.Beds = house_df.Beds.astype(float)
except:
    print('Data already converted')
try:
    house_df.Bath = house_df.Bath.astype(float)
except:
    print('Data already converted')
try:
    house_df.Prices = house_df.Prices.replace('[\$,]', '', regex = True).astype(float)
except:
    print('Data already converted')
    
house_df
# Out:
# Data already converted
# Data already converted
#       Prices  Beds Baths SquareFt                                   Loc
# 0   209000.0   3.0     2        1                North Chesterfield, VA
# 1   349500.0   4.0     2        3                North Chesterfield, VA
# 2   309900.0   4.0     3        2                        Midlothian, VA
# 3   339900.0   4.0     3        2                        Midlothian, VA
# 4   390000.0   3.0     2        2                   Charlottesville, VA
# 5   445900.0   4.0     4        3                        Midlothian, VA
# 6   275000.0   3.0     2        1                    Fredericksburg, VA
# 7   230000.0   3.0     2        1                      Chesterfield, VA
# 8   550000.0   4.0     3        2                   Charlottesville, VA
# 9   450000.0   4.0     4        3                        Midlothian, VA
# 10  259950.0   4.0     2        1                      Chesterfield, VA
# 11  375000.0   3.0     2        1                           Suffolk, VA
# 12  299750.0   4.0     2        1         South Norfolk, Chesapeake, VA
# 13  259000.0   3.0     2        1              Cedarhurst, Richmond, VA
# 14  375000.0   4.0     3        2                Amelia Court House, VA
# 15  245000.0   3.0     2        1                  Fulton, Richmond, VA
# 16  370000.0   4.0     3        2                    Mechanicsville, VA
# 17  280000.0   4.0     3        2                      Chesterfield, VA
# 18  270000.0   4.0     3        2  Western Branch South, Chesapeake, VA
# 19  359000.0   4.0     3        3                    Mechanicsville, VA
# 20  365000.0   4.0     3        3                North Chesterfield, VA
# 21  275000.0   3.0     2        1                          Powhatan, VA
# 22  330000.0   4.0     3        2                        Midlothian, VA
# 19  359000.0   4.0     3        3                    Mechanicsville, VA
# 20  365000.0   4.0     3        3                North Chesterfield, VA
# 21  275000.0   3.0     2        1                          Powhatan, VA
# 22  330000.0   4.0     3        2                        Midlothian, VA
# 23  119000.0   4.0     4        2                           Waverly, VA
# 24  250000.0   4.0     3        2  Western Branch South, Chesapeake, VA
# 25  257500.0   3.0     2        1                           Chester, VA
# 26  294950.0   4.0     3        2                           Chester, VA
# 27  269950.0   4.0     2        1                    Mechanicsville, VA
# 28  285000.0   3.0     3        1                      Chesterfield, VA
# 29  389000.0   5.0     3        2                        Midlothian, VA
# 30  209000.0   3.0     2        1                North Chesterfield, VA
# 31  349500.0   4.0     2        3                North Chesterfield, VA
# 32  309900.0   4.0     3        2                        Midlothian, VA
# 33  339900.0   4.0     3        2                        Midlothian, VA
# 34  390000.0   3.0     2        2                   Charlottesville, VA
# 35  445900.0   4.0     4        3                        Midlothian, VA
# 36  275000.0   3.0     2        1                    Fredericksburg, VA
# 37  230000.0   3.0     2        1                      Chesterfield, VA
# 38  550000.0   4.0     3        2                   Charlottesville, VA
# 39  450000.0   4.0     4        3                        Midlothian, VA
# 40  259950.0   4.0     2        1                      Chesterfield, VA
# 41  375000.0   3.0     2        1                           Suffolk, VA
# 42  299750.0   4.0     2        1         South Norfolk, Chesapeake, VA
# 43  259000.0   3.0     2        1              Cedarhurst, Richmond, VA
# 44  375000.0   4.0     3        2                Amelia Court House, VA
# 45  245000.0   3.0     2        1                  Fulton, Richmond, VA
# 46  370000.0   4.0     3        2                    Mechanicsville, VA
# 47  280000.0   4.0     3        2                      Chesterfield, VA
# 48  270000.0   4.0     3        2  Western Branch South, Chesapeake, VA
# 49  359000.0   4.0     3        3                    Mechanicsville, VA
# 50  365000.0   4.0     3        3                North Chesterfield, VA
# 51  275000.0   3.0     2        1                          Powhatan, VA
# 52  330000.0   4.0     3        2                        Midlothian, VA
# 53  119000.0   4.0     4        2                           Waverly, VA
# 54  250000.0   4.0     3        2  Western Branch South, Chesapeake, VA
# 55  257500.0   3.0     2        1                           Chester, VA
# 56  294950.0   4.0     3        2                           Chester, VA
# 57  269950.0   4.0     2        1                    Mechanicsville, VA
# 58  285000.0   3.0     3        1                      Chesterfield, VA
# 59  389000.0   5.0     3        2                        Midlothian, VA

# %%
house_df.groupby('Loc').count()
# Out:
#                                       Prices  Beds  Baths  SquareFt
# Loc
# Amelia Court House, VA                     2     2      2         2
# Cedarhurst, Richmond, VA                   2     2      2         2
# Charlottesville, VA                        4     4      4         4
# Chester, VA                                4     4      4         4
# Chesterfield, VA                           8     8      8         8
# Fredericksburg, VA                         2     2      2         2
# Fulton, Richmond, VA                       2     2      2         2
# Mechanicsville, VA                         6     6      6         6
# Midlothian, VA                            12    12     12        12
# North Chesterfield, VA                     6     6      6         6
# Powhatan, VA                               2     2      2         2
# South Norfolk, Chesapeake, VA              2     2      2         2
# Suffolk, VA                                2     2      2         2
# Waverly, VA                                2     2      2         2
# Western Branch South, Chesapeake, VA       4     4      4         4

# %%
features = ['Prices', 'Beds', 'Baths', 'SquareFt']

# %%
x = house_df.loc[:, features].values

y = house_df.loc[:,['Loc']].values

x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA

pca = PCA (n_components=2)

principalComponents = pca.fit_transform(x)

principal_df = pd.DataFrame(
    data = principalComponents,
    columns = ['pc1', 'pc2']
)
